# %% [markdown]
# ### Kernel Density Estimation (KDE)

# %% [markdown]
# #### 1. Trabajamos con los datos de corredores

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corredores =pd.read_csv('C:/Users/pc/Desktop/rociochavez/Rocio-Chavez-youtube-Files-master/categorias de corredores.csv')

# %%
corredores.head()
# Out:
#    Corredor  Lugar  Genero  Edad Pais      Tiempo Velocidad
# 0      3475   3592    Male    52  GBR  217.483333   Regular
# 1     13594  13853  Female    40   NY  272.550000   Regular
# 2     12012  12256    Male    31  FRA  265.283333   Regular
# 3     10236  10457  Female    33   MI  256.150000   Regular
# 4      9476   9686    Male    33   NY  252.250000   Regular

# %%
regular =corredores.loc[(corredores['Velocidad']=='Regular'), ['Velocidad', 'Edad']]
regular
# Out:
#     Velocidad  Edad
# 0     Regular    52
# 1     Regular    40
# 2     Regular    31
# 3     Regular    33
# 4     Regular    33
# ..        ...   ...
# 994   Regular    27
# 995   Regular    61
# 997   Regular    53
# 998   Regular    21
# 999   Regular    55
#
# [719 rows x 2 columns]

# %% [markdown]
# #### 2. Creamos un histograma

# %%
sns.histplot(data =regular['Edad'])
plt.title('Histograma de corredores')
plt.show()

# %% [markdown]
# #### 3. Grafico de densidad KDE

# %%
plt.rcParams['figure.figsize']=(6,4.4)
sns.histplot(data=regular['Edad'], kde=True)
plt.show()

# %% [markdown]
# #### 4. Obtenemos solamente el grafico de densidad generado mediante el metodo KDE

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
sns.kdeplot(data=regular [ 'Edad'], color ='g', shade=True)
ax.set_ylim(0, 0.06)
ax.set_xlim(0, 100)
ax.set_title('Grafico de densidad corredores velocidad regular')
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_6888\2338798301.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=regular [ 'Edad'], color ='g', shade=True)

# %% [markdown]
# #### 5. Obtenemos el histograma con su grafico de densidad filtrando la informacion dentro del codigo

# %%
data =corredores.loc[(corredores['Velocidad']=='Lento'), 'Edad']
data
# Out:
# 9     48
# 22    33
# 23    71
# 24    39
# 31    39
# Name: Edad, dtype: int64

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
sns.kdeplot(data, color='b', shade=True), 
ax.set_ylim(0, 0.06)
ax.set_xlim(0, 100)
ax.set_title('Grafico de densidad corredores velocidad regular')
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_6888\4079022445.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data, color='b', shade=True),

# %% [markdown]
# #### 6. Desplegamos todas las categorias de la variable velocidad en un solo grafico sin necesidad de dividir informacion por categorias de velocidad

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

sns.kdeplot(data=corredores, x='Edad', hue='Velocidad', shade=True), 
ax.set_ylim(0, 0.04)
ax.set_xlim(0, 100)

plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_6888\2883219711.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=corredores, x='Edad', hue='Velocidad', shade=True),

# %% [markdown]
# #### 7. Grafico de Densidad tomando en cuenta dos variables

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

sns.kdeplot(data=corredores, y='Tiempo', x='Edad', hue='Velocidad', shade=True), 
ax.set_ylim(100, 450)
ax.set_xlim(10, 80)

plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_6888\4195658327.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=corredores, y='Tiempo', x='Edad', hue='Velocidad', shade=True),
